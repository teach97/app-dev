# %%
import urllib.request

# %%
import requests

# %%
# inport BeautifulSoup

# %%
target_url = 'https://www.python.org/'
with urllib.request.urlopen(target_url, timeout=10) as response:
    status =response.status

# %%
with urllib.request.urlopen(target_url, timeout=10) as f:
    html = f.read()

print(html)
# Out:
# b'\x1f\x8b\x08\x00\x00\x00\x00\x00\x00\x03\xed}{s\xdbF\xb2\xef\xff\xa9\xda\xef0KWy\xb3\'")R\xb2\xfc\x92\x98\x95\x9fQ\xd6\xafDNr\xef=\xe7\x94\x0b\x04A\x12\x12\x08\xc0xH\xa2\xf7\xecw\xbf\xbf\xee\x99\x01\x06O\x11\x12\xe5$U\'\xbb\xb6\x89\xd7LOOOwOO?\x0e\xff:\x0b\xecd\x1d:b\x99\xac\xbc\xc97\x87\xf4\x8f\xb0=+\x8e\x8fz~\xd0?\x8b{\xc2\xb3\xfc\xc5Q\xcf\xf1{b\xe6FG=/\x89z\x93o\xf0\xa6c\xcd&\xdf\x08\xfcw\x18\xdb\x91\x1b&b\xe6\xcc\x9d\x88\xef\xe8\xff\xe6\xae\xe7\xf4\xa9y\xb46\xfd2\xde\xb1\x97\xab\x9d\xd9j\xb1\xe3\\9;\x8b/;gq\xe0\xef\xacb\x97\xfe\\\xed\x84\xb3\xf9Nx\xbe\xd8I\xf0\xe4\xea\xcb\xce\x177\xec\x15\x1a\x9bY\x89\xd5\x9f\x05+\xcb\xf5\x8fz\xe1:Y\x06\xfe \x88\x16\xc5\x97\xe2\xc8>\xea-\x93$\x8c\x9f\x0c\x87\x96oy\xeb\xc4\xb5\xe3A\xfe\xfa\xf0,\x1eJx\x07\x0c\xdd,\xb8\xf4\xbd\xc0\x9a\xc5\x83 M\xa6A\xea\xcf\xfa\x9e\xeb\x9f\xc7\x03\x0c}r\xa8^\xc5xy\xa0+\'\xb1\x84\xbd\xb4\xa2\xd8I\x8ezi2\xef?"\\\xf03\xfaJD\x8e\x07\xd8" "\xb1\x97=\xb1\xc4\xaf\xa3\x1e\x009\xb3\xae\x06\x8b Xx\x8e\x15\xba\xf1\xc0\x0eV|o
# ...

# %%
import os
os.getcwd()
os.path.abspath('heloo.html')
# Out:
# 'c:\\Users\\Playdata\\Desktop\\study\\app-dev'

# %%
file_url = 'file:///'+os.path.abspath('hello.html')
file_url
# Out:
# 'file:///c:\\Users\\Playdata\\Desktop\\study\\app-dev\\hello.html'

# %%
with urllib.request.urlopen(file_url) as f:
    html = f.read().decode('utf-8')

print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Teach's Document</title>
# </head>
# <body>
#     <!-- 여기는 주석입니다.-->
#     안녕하시렵니까
# </body>
# </html>

# %%
from urllib.request import urlopen
from urllib.error import HTTPError, URLError

url = "https://www.python.org/"

try:
    with urlopen(url, timeout=10) as response:
        # HTTP 상태 코드
        print("상태 코드:", response.status)

        # 응답 헤더에서 인코딩 확인
        encoding = response.headers.get_content_charset() or "utf-8"

        # read() 결과는 bytes이므로 문자열로 변환
        html = response.read().decode(encoding)

        print(html[:500])

except HTTPError as error:
    print("HTTP 오류:", error.code, error.reason)

except URLError as error:
    print("URL 오류:", error.reason)

except TimeoutError:
    print("요청 시간이 초과되었습니다.")
# Out:
# 상태 코드: 200
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[20], line 25
#      21
#      22 except URLError as error:
#      23     print("URL 오류:", error.reason)
#      24
# ---> 25 except TimeoutError:
#      26     print("요청 시간이 초과되었습니다.")
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8b in position 1: invalid start byte

# %% [markdown]
# # requests 소개

# %%
index_url = "http://127.0.0.1:8000/static/index.html"
res = requests.get(index_url)
res
# Out:
# <Response [200]>

# %%
print(res.text[:200])
# Out:
# <script language=javascript src="/template/head_js.naver?referer=info.finance.naver.com&menu=marketindex&submenu=market"></script>
# <script type="text/javascript" src="https://ssl.pstatic.net/imgstock

# %% [markdown]
# # httpx

# %%
import httpx
async def fetch_data():
    with httpx.AsyncClient() as client:
        respones = await client.get('https://example.com/api')

    return respones.json()

# %%
@app.get("/weather/raw")
async def weather_raw():
    async with httpx.AsyncClient(timeout=5.0) as client:
        response = await client.get(
"https://api.open-meteo.com/v1/forecast"
,
params={
"latitude": 36.8,
"longitude": 127.1,
"current": "temperature_2m"
,
},
)
    return response.json()

# %%
call_url = "https://api.open-meteo.com/v1/forecast?latitude=36.8&longitude=127.1&current=temperature_2m,relative_humidity_2m&timezone=Asia/Seoul"
call_url
# Out:
# 'https://api.open-meteo.com/v1/forecast?latitude=36.8&longitude=127.1&current=temperature_2m,relative_humidity_2m&timezone=Asia/Seoul'

# %%
# request
# 1번 방식
import requests
response = requests.get(call_url, timeout=5)
response.json()
# Out:
# {'latitude': 36.8,
#  'longitude': 127.125,
#  'generationtime_ms': 0.03647804260253906,
#  'utc_offset_seconds': 32400,
#  'timezone': 'Asia/Seoul',
#  'timezone_abbreviation': 'GMT+9',
#  'elevation': 42.0,
#  'current_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature_2m': '°C',
#   'relative_humidity_2m': '%'},
#  'current': {'time': '2026-08-14T12:15',
#   'interval': 900,
#   'temperature_2m': 28.4,
#   'relative_humidity_2m': 75}}

# %%
# 2번 방식
import requests
response = requests.get(only_url,
                        params=params_value,
                        timeout=5) #sync

response.json()
# Out:
# {'latitude': 36.8,
#  'longitude': 127.125,
#  'generationtime_ms': 0.03600120544433594,
#  'utc_offset_seconds': 32400,
#  'timezone': 'Asia/Seoul',
#  'timezone_abbreviation': 'GMT+9',
#  'elevation': 42.0,
#  'current_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature_2m': '°C',
#   'relative_humidity_2m': '%'},
#  'current': {'time': '2026-08-14T12:15',
#   'interval': 900,
#   'temperature_2m': 28.4,
#   'relative_humidity_2m': 75}}

# %%
only_url = "https://api.open-meteo.com/v1/forecast"
params_value = {
        "latitude": 36.8,
        "longitude": 127.1,
        "current": "temperature_2m,relative_humidity_2m",
        "timezone": "Asia/Seoul",
    }

params_value
# Out:
# {'latitude': 36.8,
#  'longitude': 127.1,
#  'current': 'temperature_2m,relative_humidity_2m',
#  'timezone': 'Asia/Seoul'}

# %%
# httpx
import httpx

async def get_weather():
    async with httpx.AsyncClient(timeout=5) as client:
        response = await client.get(
            only_url,
            params = params_value,

        )
        data = response.json()

    return data

# %%
result = await get_weather()
print(result)
# Out:
# {'latitude': 36.8, 'longitude': 127.125, 'generationtime_ms': 0.03445148468017578, 'utc_offset_seconds': 32400, 'timezone': 'Asia/Seoul', 'timezone_abbreviation': 'GMT+9', 'elevation': 42.0, 'current_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature_2m': '°C', 'relative_humidity_2m': '%'}, 'current': {'time': '2026-08-14T12:30', 'interval': 900, 'temperature_2m': 28.6, 'relative_humidity_2m': 73}}

# %%
import httpx
@app.get("/weather/raw")
async def weather_raw():
    async with httpx.AsyncClient(timeout=5.0) as client:
        response = await client.get(
           "https://api.open-meteo.com/v1/forecast",
            params={
                "latitude": 36.8,
                "longitude": 127.1,
                "current": "temperature_2m",},)
        return response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 import httpx
# ----> 2 @app.get("/weather/raw")
#       3 async def weather_raw():
#       4     async with httpx.AsyncClient(timeout=5.0) as client:
#       5         response = await client.get(
#
# NameError: name 'app' is not defined

# %% [markdown]
# # Books API AIzaSyDe_9NmTVYRUi3zaniMlcOI5hW3LIZrmB0

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()
# os.getenv('GOOGLE_BOOKS_API_KEY')
# Out:
# True

# %%
API_KEY = os.getenv('GOOGLE_BOOKS_API_KEY')

response = requests.get(
    "https://www.googleapis.com/books/v1/volumes",
    params={
        "q": "파이썬",
        "key": API_KEY,
    },
    timeout=5.0,

)

data = response.json()
print("총 검색 수:", data.get("totalItems"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 API_KEY = os.getenv('GOOGLE_BOOKS_API_KEY')
#       2
#       3 response = requests.get(
#       4     "https://www.googleapis.com/books/v1/volumes",
#
# NameError: name 'os' is not defined

# %%
data
# Out:
# {'kind': 'books#volumes',
#  'totalItems': 300,
#  'items': [{'kind': 'books#volume',
#    'id': '5s02ygEACAAJ',
#    'etag': 'pBNI4NCoDmE',
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/5s02ygEACAAJ',
#    'volumeInfo': {'title': 'Do it! 점프 투 파이썬',
#     'authors': ['박응용'],
#     'publishedDate': '2019',
#     'industryIdentifiers': [{'type': 'ISBN_13',
#       'identifier': '9791163030911'}],
#     'readingModes': {'text': False, 'image': False},
#     'pageCount': 356,
#     'printType': 'BOOK',
#     'categories': ['Computer programming'],
#     'maturityRating': 'NOT_MATURE',
#     'allowAnonLogging': False,
#     'contentVersion': 'preview-1.0.0',
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'language': 'ko',
#     'previewLink': 'http://books.google.co.kr/books?id=5s02ygEACAAJ&dq=%ED%8C%8C%EC%9D%B4%EC%8D%AC&hl=&cd=1&source=gbs_api',
# ...
